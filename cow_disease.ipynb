# %%
ROOT_DIR = 'C:\\Users\\arul\\Downloads\\Compressed\\cow_disease'

# %%
import torch

# Check if GPU is available
if torch.cuda.is_available():
    # If GPU is available, set the device to GPU
    device = torch.device("cuda")
    print("GPU is available!")
else:
    # If GPU is not available, set the device to CPU
    device = torch.device("cpu")
    print("GPU is not available, using CPU instead.")
# Out:
# GPU is available!

# %%
print("PyTorch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("CUDA version:", torch.version.cuda)
print("GPU device name:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "No GPU")
# Out:
# PyTorch version: 2.3.0+cu121
# CUDA available: True
# CUDA version: 12.1
# GPU device name: NVIDIA GeForce RTX 3060 Ti

# %%
import os

from ultralytics import YOLO


# Load a model
model = YOLO("yolov8n.yaml")  # build a new model from scratch

# Use the model
results = model.train(data=os.path.join(ROOT_DIR, "data.yaml"), epochs=25)
# Out:
# Ultralytics YOLOv8.2.22  Python-3.11.4 torch-2.3.0+cu121 CUDA:0 (NVIDIA GeForce RTX 3060 Ti, 8192MiB)
# ...

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# c:\Users\arul\Downloads\Compressed\cow_disease

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# %%
ls "c:\Users\arul\Downloads\Compressed\cow_disease\runs\detect\train\"
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is EA67-1110
#
#  Directory of c:\Users\arul\Downloads\Compressed\cow_disease\runs\detect\train
#
# 19-05-2024  07:39    <DIR>          .
# 19-05-2024  07:40    <DIR>          ..
# 19-05-2024  07:35             1,674 args.yaml
# 19-05-2024  07:39            95,528 confusion_matrix.png
# 19-05-2024  07:39            99,000 confusion_matrix_normalized.png
# 19-05-2024  07:39           218,928 events.out.tfevents.1716084304.DESKTOP-BSNDQFL.11152.0
# 19-05-2024  07:39           108,003 F1_curve.png
# 19-05-2024  07:35           170,783 labels.jpg
# 19-05-2024  07:35           174,803 labels_correlogram.jpg
# 19-05-2024  07:39            99,820 P_curve.png
# 19-05-2024  07:39            87,354 PR_curve.png
# 19-05-2024  07:39           100,990 R_curve.png
# 19-05-2024  07:39            17,187 results.csv
# 19-05-2024  07:39           270,221 results.png
# 19-05-2024  07:35           519,260 train_batch0.jpg
# ...

# %%
from ultralytics import YOLO

from IPython.display import display, Image
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/val_batch0_labels.jpg', width=600)
# Out:
# c:\Users\arul\Downloads\Compressed\cow_disease

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model={HOME}\runs\fine_tune\yolov8n_fine_tune\weights\best.pt conf=0.25 source="C:\Users\arul\Downloads\Video\Cow.mp4" save=True
# Out:
# c:\Users\arul\Downloads\Compressed\cow_disease
# Ultralytics YOLOv8.2.16 🚀 Python-3.11.4 torch-2.3.0+cu121 CUDA:0 (NVIDIA GeForce RTX 3060 Ti, 8192MiB)
# YOLOv8n summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# video 1/1 (frame 1/218) C:\Users\arul\Downloads\Video\Cow.mp4: 640x384 2 lumpy skin dieseases, 78.4ms
# video 1/1 (frame 2/218) C:\Users\arul\Downloads\Video\Cow.mp4: 640x384 2 lumpy skin dieseases, 6.0ms
# video 1/1 (frame 3/218) C:\Users\arul\Downloads\Video\Cow.mp4: 640x384 2 lumpy skin dieseases, 5.0ms
# video 1/1 (frame 4/218) C:\Users\arul\Downloads\Video\Cow.mp4: 640x384 (no detections), 8.0ms
# video 1/1 (frame 5/218) C:\Users\arul\Downloads\Video\Cow.mp4: 640x384 (no detections), 6.5ms
# video 1/1 (frame 6/218) C:\Users\arul\Downloads\Video\Cow.mp4: 640x384 1 lumpy skin diesease, 8.5ms
# video 1/1 (frame 7/218) C:\Users\arul\Downloads\Video\Cow.mp4: 640x384 (no detections), 5.1ms
# ...
